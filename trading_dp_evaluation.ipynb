# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from typing import Tuple
from seaborn import heatmap
from tqdm import tqdm
from scipy.stats import norm
from trading_dp import make_transition_matrix, run_dp

# %%
# Polymarket data
market_df = pd.read_csv("data/polymarket_markets.csv")
market_df.head()
# Out:
# /var/folders/tg/97wz__w559g0wrgwt_t2pmd00000gp/T/ipykernel_41870/541252775.py:1: DtypeWarning: Columns (0,5,9,16,26,28,29,32,36,39,40,42,44,47,63,64,65,69,70,85,93,94,95,96,99,103,108,111,114,137) have mixed types. Specify dtype option on import or set low_memory=False.
#   market_df = pd.read_csv("data/polymarket_markets.csv")
#   acceptingOrders acceptingOrdersTimestamp  active  approved  archived  \
# 0            True     2025-07-31T19:47:02Z    True      True     False
# 1            True     2025-07-31T19:47:04Z    True      True     False
# 2            True     2025-07-31T19:47:04Z    True      True     False
# 3            True     2025-07-31T19:47:06Z    True      True     False
# 4            True     2025-05-21T00:09:01Z    True      True     False
#
#   automaticallyActive automaticallyResolved  bestAsk  bestBid category  ...  \
# 0                True                   NaN    0.006    0.005      NaN  ...
# ...

# %%
for i in market_df.columns:
    print(i)
# Out:
# acceptingOrders
# acceptingOrdersTimestamp
# active
# approved
# archived
# automaticallyActive
# automaticallyResolved
# bestAsk
# bestBid
# category
# categoryMailchimpTag
# clearBookOnStart
# clobRewards
# clobTokenIds
# closed
# closedTime
# commentsEnabled
# competitive
# conditionId
# createdAt
# createdBy
# creator
# customLiveness
# cyom
# denominationToken
# deploying
# deployingTimestamp
# description
# disqusThread
# enableOrderBook
# endDate
# endDateIso
# eventStartTime
# event_id
# event_slug
# event_title
# featured
# fee
# feesEnabled
# formatType
# fpmmLive
# funded
# gameId
# gameStartTime
# groupItemRange
# groupItemThreshold
# groupItemTitle
# hasReviewedDates
# holdingRewardsEnabled
# icon
# id
# image
# lastTradePrice
# line
# liquidity
# liquidityAmm
# liquidityClob
# liquidityNum
# lowerBound
# mailchimpTag
# makerBaseFee
# manualActivation
# marketGroup
# marketMakerAddress
# marketType
# negRisk
# negRiskMarketID
# negRiskOther
# negRiskRequestID
# new
# ...

# %%
market_df["spread"]
# Out:
# <Axes: >

# %%
heatmap(make_transition_matrix(0.5, 0.1, 0.2, 99))
# Out:
# <Axes: >
